# %%
import timeit
import io
import os
import numpy as np
import tensorflow as tf

from PIL import Image  # 파이썬 이미지 라이브러리
import matplotlib.pyplot as plt

from keras.preprocessing.image import ImageDataGenerator

# %%
X = np.load('./211024_rgb_cnn_input.npy')
Y = np.load('./211024_rgb_cnn_target.npy')

# %%
print("인풋 세트의 배열형태: ", X.shape)
print("타겟 세트의 배열형태: ", Y.shape)
# Out:
# 인풋 세트의 배열형태:  (4504, 128, 128, 3)
# 타겟 세트의 배열형태:  (4504,)

# %%
x = np.unique(Y, return_counts=True)
damage_class = int(x[0][0])
normal_class = int(x[0][1])

damage_count = int(x[1][0])
normal_count = int(x[1][1])

print("손상 컨테이너: {}장".format(damage_count))
print("정상 컨테이너: {}장".format(normal_count))

total = damage_count + normal_count
d_ratio = damage_count/total*100
n_ratio = normal_count/total*100

print("손상 사진 비율: {0:.2f}%, 정상 사진 비율: {1:.2f}%".format(d_ratio, n_ratio))
# Out:
# 손상 컨테이너: 2272장
# 정상 컨테이너: 2232장
# 손상 사진 비율: 50.44%, 정상 사진 비율: 49.56%

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=42)
# 셔플 없이 하면 편향될 수 있음
# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, shuffle =true, random_state=42)

# %%
# 255로 나눠주어 전처리 시작
my_size = 128
X_train = X_train.reshape(X_train.shape[0], my_size, my_size, 3).astype('float32')/255
X_test = X_test.reshape(X_test.shape[0], my_size, my_size, 3).astype('float32')/255
print("훈련 세트 배열: ", X_train.shape)
print("테스트 세트 배열: ", X_test.shape)
# Out:
# 훈련 세트 배열:  (3603, 128, 128, 3)
# 테스트 세트 배열:  (901, 128, 128, 3)

# %%
# 딥러닝에 필요한 라이브러리 불러오기
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D

import tensorflow as tf

np.random.seed(3)
tf.random.set_seed(3)

# %% [markdown]
# ### cnn  구성이 깊은 모델로 해봤더니, 결과가 별로 좋지 않았다
# 모델이 무겁다고 성능이 좋은 게 아니라는 측면을 알게 되어, 가볍게 cnn을 설계 해보았다
# -  filter개수가 32개, 사이즈는 (3,3)인 conv layer 한 층을 쌓고,
# - Max pooling layer를 1개 쌓고,
# - Dense 층으로 분류를 해주었다.

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), input_shape=(128, 128, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 126, 126, 32)      896
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 127008)            0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               32514304
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 32,515,457
# Trainable params: 32,515,457
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',
             optimizer='adam', 
             metrics=['accuracy'])

# %%
history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=30, batch_size=67)

# %%
# 테스트 세트에 적용해보기
print('\n Test Accurary: %.4f' % (model.evaluate(X_test, Y_test)[1]))
# Out:
# 29/29 [==============================] - 0s 6ms/step - loss: 0.4944 - accuracy: 0.8801
#
#  Test Accurary: 0.8801

# %% [markdown]
# 2번째시도:
#     conv layer의 filter를 64로 바꾸어서 시행.
#     결과는 정확도는 조금 올라가고, loss가 조금 내려갔다.

# %%
model = Sequential()
model.add(Conv2D(64, kernel_size=(3, 3), input_shape=(128, 128, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
# model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 126, 126, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 254016)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65028352
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 65,030,401
# Trainable params: 65,030,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',
             optimizer='adam', 
             metrics=['accuracy'])

# %%
history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=30, batch_size=67)
# Out:
# Epoch 1/30
# 54/54 [==============================] - 2s 35ms/step - loss: 2.7720 - accuracy: 0.6450 - val_loss: 0.4583 - val_accuracy: 0.7791
# Epoch 2/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.3496 - accuracy: 0.8504 - val_loss: 0.3910 - val_accuracy: 0.8213
# Epoch 3/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.2240 - accuracy: 0.9201 - val_loss: 0.2826 - val_accuracy: 0.8801
# Epoch 4/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.1165 - accuracy: 0.9670 - val_loss: 0.2859 - val_accuracy: 0.8713
# Epoch 5/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0808 - accuracy: 0.9836 - val_loss: 0.2862 - val_accuracy: 0.8901
# Epoch 6/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0387 - accuracy: 0.9944 - val_loss: 0.2658 - val_accuracy: 0.9034
# Epoch 7/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0224 - accuracy: 0.9989 - val_loss: 0.3049 - val_accuracy: 0.9001
# Epoch 8/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0150 - accuracy: 0.9994 - val_loss: 0.3223 - val_accuracy: 0.8890
# Epoch 9/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0109 - accuracy: 0.9992 - val_loss: 0.3267 - val_accuracy: 0.8968
# Epoch 10/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0091 - accuracy: 0.9997 - val_loss: 0.3363 - val_accuracy: 0.8879loss: 0
# Epoch 11/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0092 - accuracy: 0.9992 - val_loss: 0.3300 - val_accuracy: 0.8990
# Epoch 12/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0073 - accuracy: 0.9989 - val_loss: 0.3263 - val_accuracy: 0.8901
# Epoch 13/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0116 - accuracy: 0.9981 - val_loss: 0.3774 - val_accuracy: 0.8713
# Epoch 14/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0097 - accuracy: 0.9994 - val_loss: 0.3538 - val_accuracy: 0.89460102 - accura
# Epoch 15/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0048 - accuracy: 0.9992 - val_loss: 0.3576 - val_accuracy: 0.8868
# Epoch 16/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0033 - accuracy: 0.9997 - val_loss: 0.3968 - val_accuracy: 0.8901
# Epoch 17/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0030 - accuracy: 0.9997 - val_loss: 0.3956 - val_accuracy: 0.8968
# Epoch 18/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.3771 - val_accuracy: 0.8946
# Epoch 19/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0036 - accuracy: 0.9994 - val_loss: 0.3935 - val_accuracy: 0.8957
# Epoch 20/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0042 - accuracy: 0.9992 - val_loss: 0.3856 - val_accuracy: 0.8923
# Epoch 21/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0030 - accuracy: 0.9997 - val_loss: 0.4472 - val_accuracy: 0.8779
# Epoch 22/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0148 - accuracy: 0.9972 - val_loss: 0.3819 - val_accuracy: 0.8779
# Epoch 23/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0078 - accuracy: 0.9983 - val_loss: 0.4181 - val_accuracy: 0.879078 - accuracy: 0.99
# Epoch 24/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0060 - accuracy: 0.9989 - val_loss: 0.4902 - val_accuracy: 0.8690
# Epoch 25/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0126 - accuracy: 0.9972 - val_loss: 0.4344 - val_accuracy: 0.8724
# Epoch 26/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0103 - accuracy: 0.9983 - val_loss: 0.4202 - val_accuracy: 0.8901
# Epoch 27/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0031 - accuracy: 0.9997 - val_loss: 0.4958 - val_accuracy: 0.8824
# Epoch 28/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 0.4484 - val_accuracy: 0.8890
# Epoch 29/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.4450 - val_accuracy: 0.8890
# Epoch 30/30
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.4716 - val_accuracy: 0.8901

# %%
# 테스트 세트에 적용해보기
print('\n Test Accurary: %.4f' % (model.evaluate(X_test, Y_test)[1]))
# Out:
# 29/29 [==============================] - 0s 5ms/step - loss: 0.4716 - accuracy: 0.8901
#
#  Test Accurary: 0.8901

# %% [markdown]
# 3번째시도:
#     conv layer의 filter를 사이즈를 키워서 (4,4)로 시행.
#     그 결과, 정확도는 조금 내려가고, loss가 조금 내려가는 효과가 있었다.

# %%
model = Sequential()
model.add(Conv2D(64, kernel_size=(4, 4), input_shape=(128, 128, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
# model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 125, 125, 64)      3136
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 62, 62, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 246016)            0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               62980352
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 62,983,745
# Trainable params: 62,983,745
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',
             optimizer='adam', 
             metrics=['accuracy'])

# %%
history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=30, batch_size=67)

# %%
# 테스트 세트에 적용해보기
print('\n Test Accurary: %.4f' % (model.evaluate(X_test, Y_test)[1]))

# %%
4번째시도:
    conv layer의 filter 사이즈를 줄여서 (2,2)로 시행.
    그 결과, 정확도는 조금 상승하고, loss가 조금 줄어드는 효과가 있었다.

# %%
model = Sequential()
model.add(Conv2D(64, kernel_size=(2, 2), input_shape=(128, 128, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
# model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(1, activation='sigmoid'))
model.summary()

# %%
model.compile(loss='binary_crossentropy',
             optimizer='adam', 
             metrics=['accuracy'])

# %%
history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=30, batch_size=67)

# %%
# 테스트 세트에 적용해보기
print('\n Test Accurary: %.4f' % (model.evaluate(X_test, Y_test)[1]))

# %% [markdown]
# 5번째 시도:
#     conv layer를 비슷한 사례의 논문을 참조하여, 층 설계방향을 닮게 해보았다
#     정확도가 92%로 상승하였고, loss가 0.6077로 나왔다.

# %%
model = Sequential()
model.add(Conv2D(64, kernel_size=(2, 2), input_shape=(128, 128, 3), activation='relu'))
model.add(Conv2D(128, kernel_size=(2, 2), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(256, kernel_size=(2, 2), activation='relu'))
model.add(Conv2D(512, kernel_size=(2, 2), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
# model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(1, activation='sigmoid'))
model.summary()

# %%
model.compile(loss='binary_crossentropy',
             optimizer='adam', 
             metrics=['accuracy'])

# %%
history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=30, batch_size=67)

# %%
# 테스트 세트에 적용해보기
print('\n Test Accurary: %.4f' % (model.evaluate(X_test, Y_test)[1]))
